# %% [markdown]
# # basic visualization tools

# %% [markdown]
# # line chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
s=pd.read_csv(r'C:\Users\chanti\Desktop\linear.csv')
df=pd.DataFrame(s)
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df1=df.head(10)
df1
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
# 6                 Sub-Saharan Africa                 Angola        Household
# 7                 Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                 Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                 Sub-Saharan Africa                Senegal           Cereal
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# ...

# %%
plt.plot(df['Unit Cost'])
plt.plot(df['Total Profit'])


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
s=pd.read_csv(r'C:\Users\chanti\Desktop\salary.csv')
df2=pd.DataFrame(s)
df2
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
plt.plot(df2['YearsExperience'])
plt.plot(df2['Salary'])

plt.show()

# %% [markdown]
# # bar chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
s=pd.read_csv(r'C:\Users\chanti\Desktop\salary.csv')
df3=pd.DataFrame(s)
df3
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
df3.plot(kind='bar',x='YearsExperience',linestyle='--')

plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('salary')

plt.show()

# %%
df1.plot(kind='bar',x='Unit Cost',linestyle='--')

plt.xlabel('Unit Cost')
plt.ylabel('Unit Price')
plt.title('bar graph')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 df1.plot(kind='bar',x='Unit Cost',linestyle='--')
#       3 plt.xlabel('Unit Cost')
#       4 plt.ylabel('Unit Price')
#
# NameError: name 'df1' is not defined

# %% [markdown]
# # histogram

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={'name':['anusha','indira','ramesh','pujitha','laxmi','naidu'],
      'height':[60,61,63,65,61,60],
      'weight':[47,89,52,58,50,47]
}
df=pd.DataFrame(data)
df.plot(kind='hist',ec="black")

plt.show()

# %%
df3.plot(kind='hist',x='YearsExperience',linestyle='--')

plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('salary')
plt.show()

# %% [markdown]
# # area charts

# %%
import pandas as pd
import matplotlib.pyplot as plt
x=range(1,8)
y=[1,4,6,8,4,23,2]
plt.fill_between(x,y)
plt.show()

# %% [markdown]
# # specialized visualization tools
#
# # scatter plot

# %%
import numpy as np
import matplotlib.pyplot as plt
discount=np.array([10,20,30,40,50])
saleInRs=np.array([40000,45000,48000,50000,100000])
plt.scatter(x=discount,y=saleInRs)
plt.title('sales vs discount')
plt.xlabel('discount offered')
plt.ylabel('saies in Rs')
plt.show()

# %% [markdown]
# # box plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data={'name':['anusha','indira','poojitha','ramesh','laxmi','naidu'],
      'english':[95,45,78,34,78,99],
      'maths':[67,78,45,78,99,89],
      'hindi':[67,87,45,89,45,65],
      'science':[68,43,89,56,98,67]      
}
df=pd.DataFrame(data)
df.plot(kind='box',color='red',title='Compare Resorts')
plt.title('performance analysis')
plt.xlabel('subjects')
plt.ylabel('marks')
plt.show()

# %% [markdown]
# # pie chart

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.DataFrame({'mass':[10,55,35],},
               index=['mercury','venus','earth'])
df.plot(kind='pie',y='mass')
plt.show()
