# %%
#________1______
import pandas as pd
df=pd.read_csv("ex2.csv")
df
# Out:
#      row.names  sbp  tobacco    ldl  adiposity  famhist  typea  obesity  \
# 0            1  160    12.00   5.73      23.11  Present     49    25.30
# 1            2  144     0.01   4.41      28.61   Absent     55    28.87
# 2            3  118     0.08   3.48      32.28  Present     52    29.14
# 3            4  170     7.50   6.41      38.03  Present     51    31.99
# 4            5  134    13.60   3.50      27.78  Present     60    25.99
# ..         ...  ...      ...    ...        ...      ...    ...      ...
# 457        459  214     0.40   5.98      31.72   Absent     64    28.45
# 458        460  182     4.20   4.41      32.10   Absent     52    28.61
# 459        461  108     3.00   1.59      15.23   Absent     40    20.09
# 460        462  118     5.40  11.61      30.79   Absent     64    27.35
# 461        463  132     0.00   4.82      33.41  Present     62    14.70
#
#      alcohol  age  chd
# 0      97.20   52    1
# 1       2.06   63    1
# 2       3.81   46    0
# ...

# %%
df.shape
# Out:
# (462, 11)

# %%
df.describe()
# Out:
#         row.names         sbp     tobacco         ldl   adiposity       typea  \
# count  462.000000  462.000000  462.000000  462.000000  462.000000  462.000000
# mean   231.935065  138.326840    3.635649    4.740325   25.406732   53.103896
# std    133.938585   20.496317    4.593024    2.070909    7.780699    9.817534
# min      1.000000  101.000000    0.000000    0.980000    6.740000   13.000000
# 25%    116.250000  124.000000    0.052500    3.282500   19.775000   47.000000
# 50%    231.500000  134.000000    2.000000    4.340000   26.115000   53.000000
# 75%    347.750000  148.000000    5.500000    5.790000   31.227500   60.000000
# max    463.000000  218.000000   31.200000   15.330000   42.490000   78.000000
#
#           obesity     alcohol         age         chd
# count  462.000000  462.000000  462.000000  462.000000
# mean    26.044113   17.044394   42.816017    0.346320
# std      4.213680   24.481059   14.608956    0.476313
# ...

# %%
df.count()
# Out:
# row.names    462
# sbp          462
# tobacco      462
# ldl          462
# adiposity    462
# famhist      462
# typea        462
# obesity      462
# alcohol      462
# age          462
# chd          462
# dtype: int64

# %%
df.value_counts()
# Out:
# row.names  sbp  tobacco  ldl   adiposity  famhist  typea  obesity  alcohol  age  chd
# 1          160  12.00    5.73  23.11      Present  49     25.30    97.20    52   1      1
# 319        114  1.20     3.98  14.90      Absent   49     23.79    25.82    26   0      1
# 317        154  1.40     1.72  18.86      Absent   58     22.67    43.20    59   0      1
# 316        190  5.15     6.03  36.59      Absent   42     30.31    72.00    50   0      1
# 315        174  0.00     3.27  35.40      Absent   58     37.71    24.95    44   0      1
#                                                                                        ..
# 151        148  6.00     6.49  26.47      Absent   48     24.70    0.00     55   0      1
# 150        124  15.50    5.05  24.06      Absent   46     23.22    0.00     61   1      1
# 149        136  1.50     6.06  26.54      Absent   54     29.38    14.50    33   1      1
# ...

# %%
#________2___________
df.loc[df.famhist == 'Present', 'famhist'] = 1
df.loc[df.famhist == 'Absent', 'famhist'] = 0
df
# Out:
#      row.names  sbp  tobacco    ldl  adiposity famhist  typea  obesity  \
# 0            1  160    12.00   5.73      23.11       1     49    25.30
# 1            2  144     0.01   4.41      28.61       0     55    28.87
# 2            3  118     0.08   3.48      32.28       1     52    29.14
# 3            4  170     7.50   6.41      38.03       1     51    31.99
# 4            5  134    13.60   3.50      27.78       1     60    25.99
# ..         ...  ...      ...    ...        ...     ...    ...      ...
# 457        459  214     0.40   5.98      31.72       0     64    28.45
# 458        460  182     4.20   4.41      32.10       0     52    28.61
# 459        461  108     3.00   1.59      15.23       0     40    20.09
# 460        462  118     5.40  11.61      30.79       0     64    27.35
# 461        463  132     0.00   4.82      33.41       1     62    14.70
#
#      alcohol  age  chd
# 0      97.20   52    1
# 1       2.06   63    1
# 2       3.81   46    0
# ...

# %%
import matplotlib.pyplot as plt

plt.bar(x,y,color="pink",edgecolor="blue")
# Out:
# <BarContainer object of 462 artists>

# %%
#__________3________
import pandas as pd
import seaborn as sns
df=pd.read_csv("ex2.csv")
x=df[["age","sbp"]].corr()
sns.heatmap(x)
# Out:
# <AxesSubplot:>

# %%
#________4______

# %%
#______6________
df["agegroup"]=pd.cut(df.age,bins=[0,20,40,60],labels=["0-18","18-45","45-60"]))
