# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([2,34,4,5,6])
y=np.array([23,4,5,8,8])
plt.scatter(x,y)
plt.show()

# %%
x=np.array([2,34,4,5,6])
y=np.array([23,4,5,8,8])
plt.scatter(x,y)
plt.show()
#second
x=np.array([2,3,4,5,6])
y=np.array([2,4,5,8,8])
plt.scatter(x,y)
plt.show()

# %%
x=np.array([2,34,4,5,6])
y=np.array([23,4,5,8,8])
plt.scatter(x,y)
#plt.show()
#second
x=np.array([2,3,4,5,6])
y=np.array([2,4,5,8,8])
plt.scatter(x,y)


plt.show()

# %%
x=np.array([2,34,4,5,6])
y=np.array([23,4,5,8,8])
plt.scatter(x,y,color="hotpink")
plt.colorbar()
plt.show()

# %%
#color for each dot
a=np.array([2,3,4,52,66])
b=np.array([2,48,5,81,8])
rangulu = np.array(["red","green","blue","yellow","pink"])

plt.scatter(a, b, c=rangulu)

plt.show()
