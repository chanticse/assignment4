# %%
# create new column
import pandas as pd
df=pd.read_csv("bin1.csv")
df
# Out:
#   person  age
# 0    few   10
# 1   gewr   15
# 2   fwer   23
# 3    rgw   30
# 4   fgwe   40
# 5   wrfw   50

# %%
df["new column"]=pd.cut(df.age,bins=[0,20,40,60],labels=["0-18","18-45","45-60"])
df
# Out:
#   person  age new column
# 0    few   10       0-18
# 1   gewr   15       0-18
# 2   fwer   23      18-45
# 3    rgw   30      18-45
# 4   fgwe   40      18-45
# 5   wrfw   50      45-60

# %% [markdown]
# ## continuous variables to binning

# %%
import pandas as pd
df=pd.read_csv("bin2.csv")
df
# Out:
#   player  age
# 0      x   20
# 1      t   34
# 2     gf   23
# 3     yt   40
# 4     ur   36
# 5   yers   28
# 6   uydr   35
# 7     es   28
# 8     tt   30
# 9    rys   40

# %%
df["new column"]=pd.cut(df.age,bins=[0,20],labels=["0-18"])
df
# Out:
#   player  age new column
# 0      x   20       0-18
# 1      t   34        NaN
# 2     gf   23        NaN
# 3     yt   40        NaN
# 4     ur   36        NaN
# 5   yers   28        NaN
# 6   uydr   35        NaN
# 7     es   28        NaN
# 8     tt   30        NaN
# 9    rys   40        NaN

# %%
 df["new column"]=pd.cut(df.age,bins=[0,20,40,60],labels=["0-18","18-45","45-60"])
df
# Out:
#   player  age new column
# 0      x   20       0-18
# 1      t   34      18-45
# 2     gf   23      18-45
# 3     yt   40      18-45
# 4     ur   36      18-45
# 5   yers   28      18-45
# 6   uydr   35      18-45
# 7     es   28      18-45
# 8     tt   30      18-45
# 9    rys   40      18-45

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 df["new column"]=pd.cut(df.age,bins=[0,20,40,60],labels=["0-18"])
#       2 df
#
# File ~\Music\chanti\lib\site-packages\pandas\core\reshape\tile.py:292, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     289     if (np.diff(bins.astype("float64")) < 0).any():
#     290         raise ValueError("bins must increase monotonically.")
# --> 292 fac, bins = _bins_to_cuts(
#     293     x,
#     294     bins,
#     295     right=right,
#     296     labels=labels,
#     297     precision=precision,
#     298     include_lowest=include_lowest,
#     299     dtype=dtype,
#     300     duplicates=duplicates,
#     301     ordered=ordered,
#     302 )
#     304 return _postprocess_for_cut(fac, bins, retbins, dtype, original)
#
# ...
